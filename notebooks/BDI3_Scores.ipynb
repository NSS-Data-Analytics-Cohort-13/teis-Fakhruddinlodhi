# %%
import pandas as pd
pd.options.display.max_columns = None
#method 2 pd.set_option('display.max_columns', None)

# %%
bdi3 = pd.read_excel("../data/NSS data_BDI3 Scores 20230101 20240630_Compiled_20241107.xlsx")

# %%
bdi3.shape
# Out:
# (34979, 228)

# %%
bdi3_entry = bdi3[['TEIDS Child ID' ,'Adaptive-Self Care Date of Testing']]

# %%
bdi3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34979 entries, 0 to 34978
# Columns: 228 entries, Last Name to Cognitive-Perception and Concepts NCE
# dtypes: datetime64[ns](13), float64(119), object(96)
# memory usage: 60.8+ MB

# %%
bdi2 = pd.read_csv("../data/NSS data_BDI2 scores_20200101-20230131_20241106.csv")
# Out:
# C:\Users\fakhr\AppData\Local\Temp\ipykernel_27368\2366034627.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   bdi2 = pd.read_csv("../data/NSS data_BDI2 scores_20200101-20230131_20241106.csv")

# %%
bdi2
# Out:
#         StudentID  studentAssessmentID  resultStudentDomainID  \
# 0         2224693              8625078              138104116
# 1         2224693              8625078              138104117
# 2         2224693              8625078              138104118
# 3         2224693              8625078              138104119
# 4         2224693              8625078              138104120
# ...           ...                  ...                    ...
# 325681    2319431              8761874              140602545
# 325682    2319431              8761874              140602546
# 325683    2319431              8761874              140602547
# 325684    2319431              8761874              140602548
# 325685    2319431              8761874              140602549
#
#        Student TEIDS ID  domainID                     domainText  ScoreTypeID  \
# 0                 52101         7                      Self-Care          2.0
# ...

# %%
#bdi2.head(20)

# %%
eco = pd.read_excel("../data/NSS_ECO Data Ind 3 FFY 2023-24 20241211.xlsx", sheet_name="ECO with Exit23-24 ")

# %%
eco.shape
# Out:
# (9999, 152)

# %%
#eco.head(10)

# %%
#bdi2['Student TEIDS ID']=bdi2['Student TEIDS ID'].astype(str)
#bdi3['TEIDS Child ID'] = bdi3['TEIDS Child ID'].astype(str)
#merged_data = pd.merge(bdi2,bdi3, on='StudentID', how='inner')

# %%
#m6 = eco[eco['<Calc> Day count 182 days +']==1]

# %%
#m6

# %%
eco1 = eco[['CHILD_ID' ,'Initial IFSP Date','ECO_Entry_DATE','ECO_Exit_DATE']]

# %%
bdi2_entry = bdi2[['Student TEIDS ID' ,'testDate','lastUpdateDate']]

# %%
bdi3_entry = bdi3[['TEIDS Child ID' ,'Adaptive-Self Care Date of Testing']]

# %%
bdi3_entry
# Out:
#        TEIDS Child ID Adaptive-Self Care Date of Testing
# 0            474074.0                         2023-09-13
# 1            474186.0                         2023-10-26
# 2            474641.0                         2023-07-31
# 3            474848.0                         2023-08-04
# 4            474967.0                         2023-07-31
# ...               ...                                ...
# 34974             NaN                         2023-11-29
# 34975             NaN                         2023-12-01
# 34976             NaN                         2023-12-04
# 34977             NaN                         2023-12-06
# 34978             NaN                         2024-04-09
#
# [34979 rows x 2 columns]

# %%
#bdi3_entry['TEIDS Child ID'] = bdi3_entry['TEIDS Child ID'].fillna(0.0)
#bdi3_entry['TEIDS Child ID'] = bdi3_entry['TEIDS Child ID'].astype(str).astype(str).str.replace('.0', '').astype(int)

# %%
eo= pd.merge(eco1, bdi2_entry, left_on= 'CHILD_ID',right_on='Student TEIDS ID', how='left')

# %%
eo1= pd.merge(eo, bdi3_entry, left_on= 'CHILD_ID',right_on='TEIDS Child ID', how='left')

# %%
eo1.head(50)
# Out:
#    CHILD_ID Initial IFSP Date ECO_Entry_DATE ECO_Exit_DATE Student TEIDS ID  \
# 0    473991        2020-01-07     2020-01-07    2022-12-27              NaN
# 1    474186        2020-01-14     2020-02-13    2023-10-26              NaN
# 2    474575        2020-01-17     2020-01-17    2020-07-29              NaN
# 3    474623        2020-01-22     2019-01-22    2022-12-16           474623
# 4    474623        2020-01-22     2019-01-22    2022-12-16           474623
# 5    474623        2020-01-22     2019-01-22    2022-12-16           474623
# 6    474623        2020-01-22     2019-01-22    2022-12-16           474623
# 7    474623        2020-01-22     2019-01-22    2022-12-16           474623
# 8    474623        2020-01-22     2019-01-22    2022-12-16           474623
# 9    474623        2020-01-22     2019-01-22    2022-12-16           474623
# 10   474623        2020-01-22     2019-01-22    2022-12-16           474623
# ...

# %%
#eo1[eo1['CHILD_ID']==504273]
#eco1.groupby(['CHILD_ID','name']).sum('total_claim_count').sort_values(by='total_claim_count', ascending=False)
eco1.[eco1['CHILD_ID']].unique()#['testDate'].nsmallest(1)#.nlargest(1,'Adaptive-Self Care Date of Testing')#.sort_values(by='total_claim_count', ascending=False)
# Out:
#   Cell In[23], line 3
#     eco1.[eco1['CHILD_ID']].unique()#['testDate'].nsmallest(1)#.nlargest(1,'Adaptive-Self Care Date of Testing')#.sort_values(by='total_claim_count', ascending=False)
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# def categorize(value):
#     if value <= 30:
#         return 'Low'
#     elif 30 < value <= 120:
#         return 'Medium'
#     else:
#         return 'High'

# %%
test = bdi2.pivot(index='resultStudentDomainID', columns='domainText', values='DQScore')

# %%
test1 = test[['Adaptive', 'Personal-Social', 'Communication', 'Motor', 'Cognitive']]

# %%
tes = pd.merge(bdi2, test1, on='resultStudentDomainID')

# %%
tes
# Out:
#         StudentID  studentAssessmentID  resultStudentDomainID  \
# 0         2224693              8625078              138104116
# 1         2224693              8625078              138104117
# 2         2224693              8625078              138104118
# 3         2224693              8625078              138104119
# 4         2224693              8625078              138104120
# ...           ...                  ...                    ...
# 325681    2319431              8761874              140602545
# 325682    2319431              8761874              140602546
# 325683    2319431              8761874              140602547
# 325684    2319431              8761874              140602548
# 325685    2319431              8761874              140602549
#
#        Student TEIDS ID  domainID                     domainText  ScoreTypeID  \
# 0                 52101         7                      Self-Care          2.0
# ...
